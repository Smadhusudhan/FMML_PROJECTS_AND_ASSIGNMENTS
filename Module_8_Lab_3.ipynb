# %% [markdown]
# <a href="https://colab.research.google.com/github/Smadhusudhan/FMML_PROJECTS_AND_ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 16:45:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  83.3MB/s    in 0.8s
#
# 2024-04-06 16:45:13 (83.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11566  1606.02421v1  In decentralized networks (of sensors, connect...  stat
# 22144  1504.05392v1  In the presence of weak overall correlation, i...  stat
# 11366  1511.03796v2  We present a framework for incorporating prior...  stat
# 16637  1704.07073v1  We propose a selective encoding model to exten...    cs
# 9297    1011.6293v2  A nonparametric Bayesian extension of Factor A...  stat
# ...             ...                                                ...   ...
# 22462  1608.01398v3  A genome-wide association study (GWAS) correla...  stat
# 6111   1607.06333v3  We design a new nonparametric method that allo...  stat
# 2974   1612.09030v2  We introduce a new paradigm to investigate uns...    cs
# 11626  1607.08456v2  Given only information in the form of similari...  stat
# 7077   1709.10222v1  We performed an empirical comparison of ICA an...  stat
#
#                                                    title  year  \
# 11566  Gossip Dual Averaging for Decentralized Optimi...  2016
# 22144  Nonparametric Testing for Heterogeneous Correl...  2015
# 11366  Learning Nonparametric Forest Graphical Models...  2015
# 16637  Selective Encoding for Abstractive Sentence Su...  2017
# 9297   Nonparametric Bayesian sparse factor models wi...  2010
# ...                                                  ...   ...
# 22462  Iterative Hard Thresholding for Model Selectio...  2016
# 6111   Uncovering Causality from Multivariate Hawkes ...  2016
# 2974   Meta-Unsupervised-Learning: A supervised appro...  2016
# 11626      Kernel functions based on triplet comparisons  2016
# 7077   Comparison of PCA with ICA from data distribut...  2017
#
#                                                 keywords
# 11566  [decentralized, connected, important, efficien...
# 22144  [correlation, investigate, correlation, signif...
# 11366  [framework, incorporating, information, nonpar...
# 16637  [selective, framework, abstractive, summarizat...
# 9297   [nonparametric, extension, superposition, pote...
# ...                                                  ...
# 22462  [association, correlates, variation, variation...
# 6111   [nonparametric, integrated, multivariate, infl...
# 2974   [introduce, investigate, unsupervised, unsuper...
# 11626  [information, similarity, approaches, construc...
# 7077   [performed, empirical, comparison, algorithms,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11566    [decentralized, connected, important, efficien...
# 22144    [correlation, investigate, correlation, signif...
# 11366    [framework, incorporating, information, nonpar...
# 16637    [selective, framework, abstractive, summarizat...
# 9297     [nonparametric, extension, superposition, pote...
#                                ...
# 2756     [multitask, approaches, organization, signific...
# 18223    [repository, generally, concerning, described,...
# 36671    [prototype, architects, developed, consisting,...
# 2702     [optimization, algorithms, evaluating, perform...
# 22394    [quadrature, important, statistics, convergenc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8718 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5e18c37-c8d0-4d8b-a554-0a34bfdf4551" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5e18c37-c8d0-4d8b-a554-0a34bfdf4551")) {                    Plotly.newPlot(                        "b5e18c37-c8d0-4d8b-a554-0a34bfdf4551",                        [{"x":["centralized","averaging","connected","regularized","simulations","maximization","important","distributed","synchronous","minimization","practical","asynchronous","communication","applications","framework","collected","constrained","optimization","convergence","theoretical","functions","inference","numerical","algorithms","illustrate","decentralized","computing","efficient","maintains","alternatives","procedures","variables","correlation","heterogeneous","significantly","properties","association","different","heterogeneity","observations","substantially","illustrates","parameters","nonparametric","pronounced","investigate","predictive","resulting","information","competing","distribution","estimating","outperform","distributions","distributional","introduce","estimation","algorithm","perspective","equivalent","reformulate","procedure","graphical","assumptions","interpretability","improvement","incorporating","structures","connectivity","parametric","summarization","representation","constructs","outperforms","experimental","performance","selective","controlling","attention","abstractive","recurrent","superposition","increasing","potentially","expression","generated","incorporate","extension","biological","application","complexity","investigated","deterministic","approximation","computational","stochastic","explained","excellent","phenomena","converges","experiments","dimensional","eigenspace","sequential","correlations","considers","technique","probability","hierarchical","processes","modelling","particular","designing","parameter","analytics","community","dirichlet","discretization","restricted","introduces","especially","correlated","dimension","demonstrate","evaluations","derivative","performances","optimizer","selection","available","suggestion","synthetic","continuous","discretized","outperforming","knowledge","generalized","structure","significant","reduction","technology","furthermore","resolution","essential","breakthroughs","involving","projection","classification","increased","dimensionality","techniques","recognition","strategic","rendering","extraction","learnable","benchmarking","decreased","approaches","operating","demonstration","limitations","volumetric","introduction","corresponding","representations","comparable","contribution","dimensions","limitation","convolutional","resolutions","traversal","accomplished","structural","characterized","proportion","alternatively","classical","objective","repeatedly","projected","computation","unlabeled","difficulty","behaviour","benchmark","classifiers","typically","additional","supervised","coordinate","partially","classifier","optimistic","traditional","assumption","partition","contrastive","distortion"],"y":[9,14,69,44,45,25,370,103,4,71,123,11,64,395,537,76,74,335,120,148,201,207,82,608,76,13,124,455,12,27,36,140,89,30,264,212,29,770,7,74,47,7,231,20,7,134,85,150,677,26,205,57,93,124,21,325,209,871,69,53,4,109,67,74,16,147,65,123,21,41,28,347,18,254,390,915,21,19,168,7,125,3,94,46,44,179,70,80,48,234,258,46,38,105,280,107,19,30,36,18,613,200,4,77,35,24,262,169,94,87,55,293,42,125,18,63,12,7,55,77,125,39,69,577,59,8,32,4,152,283,2,149,103,5,24,332,66,323,222,99,47,162,129,63,10,41,48,472,36,58,379,336,6,17,120,13,16,5,409,26,14,65,10,32,136,241,104,66,37,29,395,14,2,9,77,31,5,8,95,153,15,24,154,28,38,29,228,108,123,126,195,29,49,141,3,183,64,24,16,21],"type":"bar"},{"x":["centralized","averaging","connected","reg ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Global</span> <span style=''>Features</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Coreference</span> <span style='background-color:rgba(0, 255, 0, 0.6226415094339621);'>Resolution</span> <br/><br/><span style=''>There</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>compelling</span> <span style=''>evidence</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>coreference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>would</span> <span style=''>benefit</span> <span style=''>from</span> <span style=''>modeling</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>entity</span> <span style=''>clusters</span> <span style=''>Yet</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>with</span> <span style=''>systems</span> <span style=''>treating</span> <span style=''>each</span> <span style=''>mention</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.4385964912280702);'>attribute</span> <span style=''>to</span> <span style=''>the</span> <span style=''>inherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>of</span> <span style=''>crafting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>informative</span> <span style=''>cluster</span> <span style=''>level</span> <span style=''>features</span> <span style=''>We</span> <span style=''>instead</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.358695652173913);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(RNNs)</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>latent</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.35393258426966295);'>representations</span> <span style=''>of</span> <span style=''>entity</span> <span style=''>clusters</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>their</span> <span style=''>mentions</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.35393258426966295);'>representations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>pronominal</span> <span style=''>mentions</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporated</span> <span style=''>into</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>coreference</span> <span style=''>system</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>any</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multilinear</span> <span style=''>PCA</span> <span style=''>with</span> <span style=''>Relaxed</span> <span style=''>Start</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>(PCA)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>method</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>features</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multilinear</span> <span style=''>PCA</span> <span style=''>methods</span> <span style=''>extend</span> <span style=''>PCA</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>data</span> <span style=''>(tensors)</span> <span style=''>directly</span> <span style=''>via</span> <span style=''>tensor</span> <span style=''>to</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>or</span> <span style=''>tensor</span> <span style=''>to</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>(TVP)</span> <span style=''>However</span> <span style=''>under</span> <span style=''>the</span> <span style=''>TVP</span> <span style=''>setting</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilinear</span> <span style=''>PCA</span> <span style=''>method</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>tackles</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposing</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multilinear</span> <span style=''>PCA</span> <span style=''>(SO</span> <span style=''>MPCA)</span> <span style=''>approach</span> <span style=''>SO</span> <span style=''>MPCA</span> <span style=''>learns</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>features</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>tensors</span> <span style=''>via</span> <span style=''>TVP</span> <span style=''>by</span> <span style=''>imposing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>in</span> <span style=''>only</span> <span style=''>one</span> <span style=''>mode</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>results</span> <span style=''>in</span> <span style=''>more</span> <span style=''>cap ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Stability</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Presence</span> <span style=''>of</span> <span style=''>Multiple</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>Minimizers</span> <br/><br/><span style=''>Recently</span> <span style=''>Kutin</span> <span style=''>and</span> <span style=''>Niyogi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>several</span> <span style=''>notions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>a</span> <span style=''>property</span> <span style=''>of</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>map</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conceptually</span> <span style=''>similar</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuity</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>free</span> <span style=''>CV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>for</span> <span style=''>having</span> <span style=''>finite</span> <span style=''>VC</span> <span style='background-color:rgba(255, 0, 0, 0.3490566037735849);'>dimension</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>concerns</span> <span style=''>a</span> <span style=''>phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>ERM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjectured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>same</span> <span style=''>authors</span> <span style=''>Kutin</span> <span style=''>and</span> <span style=''>Niyogi</span> <span style=''>proved</span> <span style=''>that</span> <span style=''>ERM</span> <span style=''>on</span> <span style=''>finite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>spaces</span> <span style='background-color:rgba(0, 255, 0, 0.4390243902439024);'>containing</span> <span style=''>a</span> <span style=''>unique</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>minimizer</span> <span style=''>has</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>that</span> <span style=''>scales</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>exponentially</span> <span style=''>with</span> <span style=''>sample</span> <span style=''>siz ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>random</span> <span style=''>field</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>However</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>and</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>largely</span> <span style=''>explored</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>leaving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unification</span> <span style=''>of</span> <span style=''>these</span> <span style=''>two</span> <span style=''>concepts</span> <span style=''>ripe</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>with</span> <span style=''>unifying</span> <span style=''>these</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>models</span> <span style=''>is</span> <span style=''>in</span> <span style=''>dealing</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>feasibility</span> <span style=''>of</span> <span style=''>unifying</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>and</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>models</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>manner</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.24101103595585618)
# 	architecture (0.08401566393734425)
# 	challenging (0.10074759700961196)
# 	representation (0.1235315058739765)
# 	segmentation (0.06799572801708793)
# 	experimental (0.13883944464222142)
# 	recognition (0.11961552153791385)
# 	different (0.2741189035243859)
# 	detection (0.12922748309006765)
# 	convolutional (0.14061943752224992)
#
# Some Statistics words are:
# 	algorithm (0.394776494224008)
# 	stochastic (0.13008538422903063)
# 	estimation (0.16725263686589653)
# 	theoretical (0.14665996986438976)
# 	statistical (0.1511803114013059)
# 	distribution (0.1702661978905073)
# 	variables (0.14917127071823205)
# 	dimensional (0.17629331993972877)
# 	regression (0.1712707182320442)
# 	inference (0.19789050728277247)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e06eb15-e52b-4b07-a701-bb781e25a694" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e06eb15-e52b-4b07-a701-bb781e25a694")) {                    Plotly.newPlot(                        "0e06eb15-e52b-4b07-a701-bb781e25a694",                        [{"x":["centralized","averaging","connected","regularized","simulations","maximization","important","distributed","synchronous","minimization","practical","asynchronous","communication","applications","framework","collected","constrained","optimization","convergence","theoretical","functions","inference","numerical","algorithms","illustrate","decentralized","computing","efficient","maintains","alternatives","procedures","variables","correlation","heterogeneous","significantly","properties","association","different","heterogeneity","observations","substantially","illustrates","parameters","nonparametric","pronounced","investigate","predictive","resulting","information","competing","distribution","estimating","outperform","distributions","distributional","introduce","estimation","algorithm","perspective","equivalent","reformulate","procedure","graphical","assumptions","interpretability","improvement","incorporating","structures","connectivity","parametric","summarization","representation","constructs","outperforms","experimental","performance","selective","controlling","attention","abstractive","recurrent","superposition","increasing","potentially","expression","generated","incorporate","extension","biological","application","complexity","investigated","deterministic","approximation","computational","stochastic","explained","excellent","phenomena","converges","experiments","dimensional","eigenspace","sequential","correlations","considers","technique","probability","hierarchical","processes","modelling","particular","designing","parameter","analytics","community","dirichlet","discretization","restricted","introduces","especially","correlated","dimension","demonstrate","evaluations","derivative","performances","optimizer","selection","available","suggestion","synthetic","continuous","discretized","outperforming","knowledge","generalized","structure","significant","reduction","technology","furthermore","resolution","essential","breakthroughs","involving","projection","classification","increased","dimensionality","techniques","recognition","strategic","rendering","extraction","learnable","benchmarking","decreased","approaches","operating","demonstration","limitations","volumetric","introduction","corresponding","representations","comparable","contribution","dimensions","limitation","convolutional","resolutions","traversal","accomplished","structural","characterized","proportion","alternatively","classical","objective","repeatedly","projected","computation","unlabeled","difficulty","behaviour","benchmark","classifiers","typically","additional","supervised","coordinate","partially","classifier","optimistic","traditional","assumption","partition","contrastive","distortion","compositional","challenge","marginalizes","automaton","evaluation","composition","translated","intractable","underlying","inherently","something","forecasting","benchmarked","predictions","horizontal","respective","radiation","measurements","persistence","committee","comparisons","irradiance","autoregressive","discussed","simulation","combination","initialisation","unsupervised","flexibility","arabidopsis","illustrated","neighborhood","semiparametric","likelihood","components","determine","reliability","processor","mechanics","robustness","scheduled","execution","environment","completed","basically","minimizes","multiprocessor","processors","minimized","scheduling","sufficient","efficiency","achieving","frequently ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	detectability
# 	blockmodel
# 	overparameterized
# 	modulating
# 	forecasters
# 	deletions
# 	submodularity
# 	assortativity
# 	connectome
# 	dendrogram
# 	trainability
# 	recidivism
# 	blackwellized
# 	graphically
# 	penalised
# 	martingales
# 	transplantation
# 	statistician
# 	distilling
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	abstractive
# 	traversal
# 	automaton
# 	multiprocessor
# 	discourse
# 	adjoining
# 	megapixel
# 	judgement
# 	conversational
# 	incapability
# 	polarization
# 	multiplex
# 	employment
# 	fertility
# 	regularities
# 	luminance
# 	chrominance
# 	enrichments
# 	imperfections
# 	multiplexing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062318174858368e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7366666666666667
